# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import math

# %% [markdown]
# Download AAPL data

# %%
df = yf.download("AAPL", start="2015-01-01", end="2026-01-01")

df = df[['Close']]
df.dropna(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Log return

# %%
df['Return'] = np.log(df['Close'] / df['Close'].shift(1))
df.dropna(inplace=True)

# %% [markdown]
# Feature Engineering Entropy

# %%
def entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=False)
    prob = hist / np.sum(hist)
    prob = prob[prob > 0]
    return -np.sum(prob * np.log(prob))

window = 30

entropy_values = []
for i in range(len(df)):
    if i < window:
        entropy_values.append(np.nan)
    else:
        ent = entropy(df['Return'].iloc[i-window:i])
        entropy_values.append(ent)

df['Entropy'] = entropy_values
df.dropna(inplace=True)

# %% [markdown]
# SPLIT AND Normalize

# %%
features = df[['Close', 'Return', 'Entropy']].values

n = len(features)

train_end = int(n * 0.7)
val_end = int(n * 0.85)

train_data = features[:train_end]
val_data = features[train_end:val_end]
test_data = features[val_end:]

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# --- PARAMETERS ---
time_steps = 30

# --- SCALING ---
scaled_all = scaler.transform(features)

# --- SEQUENCE FUNCTION ---
def create_sequences(full_data, start, end, time_steps):
    X, y = [], []
    for i in range(start, end):
        if i < time_steps:
            continue
        X.append(full_data[i-time_steps:i])
        y.append(full_data[i, 0])
    return np.array(X), np.array(y)

# --- DATA SPLIT ---
X_train, y_train = create_sequences(scaled_all, time_steps, train_end, time_steps)
X_val, y_val = create_sequences(scaled_all, train_end, val_end, time_steps)
X_test, y_test = create_sequences(scaled_all, val_end, n, time_steps)

# %% [markdown]
# LSTM MODEL

# %%
model = Sequential([
    LSTM(128, return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])

model.compile(optimizer='adamW', loss='mse')

from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(patience=5, monitor="val_loss", restore_best_weights=True)

model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    callbacks=[early_stop]
)
# Out:
# c:\Users\Satri\Downloads\dataset gambar\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0089 - val_loss: 0.0018
# Epoch 2/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.9698e-04 - val_loss: 0.0011
# Epoch 3/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 4.0915e-04 - val_loss: 9.6453e-04
# Epoch 4/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.7458e-04 - val_loss: 0.0010
# Epoch 5/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.7323e-04 - val_loss: 7.7365e-04
# Epoch 6/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.5354e-04 - val_loss: 0.0012
# Epoch 7/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.9289e-04 - val_loss: 6.7388e-04
# Epoch 8/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.8597e-04 - val_loss: 6.6166e-04
# Epoch 9/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.2990e-04 - val_loss: 6.8548e-04
# Epoch 10/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.1771e-04 - val_loss: 6.0403e-04
# Epoch 11/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.9510e-04 - val_loss: 6.5935e-04
# Epoch 12/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2.1983e-04 - val_loss: 4.4801e-04
# Epoch 13/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 2.2026e-04 - val_loss: 4.2272e-04
# Epoch 14/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 1.8697e-04 - val_loss: 4.3366e-04
# Epoch 15/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 1.8565e-04 - val_loss: 4.0653e-04
# Epoch 16/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5682e-04 - val_loss: 3.7449e-04
# Epoch 17/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.6739e-04 - val_loss: 3.6861e-04
# Epoch 18/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.6877e-04 - val_loss: 3.5620e-04
# Epoch 19/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.5843e-04 - val_loss: 3.5033e-04
# Epoch 20/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 2.0940e-04 - val_loss: 5.1648e-04
# Epoch 21/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 2.5903e-04 - val_loss: 5.1980e-04
# Epoch 22/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.3447e-04 - val_loss: 4.7955e-04
# Epoch 23/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4817e-04 - val_loss: 3.3219e-04
# Epoch 24/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.5302e-04 - val_loss: 4.2545e-04
# Epoch 25/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.4546e-04 - val_loss: 5.6060e-04
# Epoch 26/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1.5270e-04 - val_loss: 3.2411e-04
# Epoch 27/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.4773e-04 - val_loss: 3.4902e-04
# Epoch 28/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.4893e-04 - val_loss: 3.0949e-04
# Epoch 29/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.5889e-04 - val_loss: 3.0906e-04
# Epoch 30/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.6548e-04 - val_loss: 3.1052e-04
# Epoch 31/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.3195e-04 - val_loss: 3.6296e-04
# Epoch 32/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 1.5491e-04 - val_loss: 6.4865e-04
# Epoch 33/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 1.7307e-04 - val_loss: 3.0093e-04
# Epoch 34/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 1.3935e-04 - val_loss: 7.9629e-04
# Epoch 35/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1.8298e-04 - val_loss: 7.6678e-04
# Epoch 36/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.7579e-04 - val_loss: 2.9940e-04
# Epoch 37/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1.7541e-04 - val_loss: 2.9877e-04
# Epoch 38/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.7069e-04 - val_loss: 3.6375e-04
# Epoch 39/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2994e-04 - val_loss: 3.2218e-04
# Epoch 40/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.5530e-04 - val_loss: 3.0030e-04
# Epoch 41/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.4518e-04 - val_loss: 2.8868e-04
# Epoch 42/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.4406e-04 - val_loss: 2.8668e-04
# Epoch 43/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.5063e-04 - val_loss: 3.1314e-04
# Epoch 44/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 1.7131e-04 - val_loss: 6.6228e-04
# Epoch 45/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.4231e-04 - val_loss: 4.1528e-04
# Epoch 46/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 1.7469e-04 - val_loss: 4.2489e-04
# Epoch 47/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 1.3098e-04 - val_loss: 7.6633e-04

# %% [markdown]
# EVALUATION

# %%
train_pred = model.predict(X_train)
val_pred   = model.predict(X_val)
test_pred  = model.predict(X_test)

def inverse_transform(pred, X):
    temp = np.zeros((len(pred), X.shape[2]))
    temp[:, 0] = pred[:, 0]
    return scaler.inverse_transform(temp)[:, 0]

train_pred_actual = inverse_transform(train_pred, X_train)
val_pred_actual   = inverse_transform(val_pred, X_val)
test_pred_actual  = inverse_transform(test_pred, X_test)

y_train_actual = inverse_transform(y_train.reshape(-1,1), X_train)
y_val_actual   = inverse_transform(y_val.reshape(-1,1), X_val)
y_test_actual  = inverse_transform(y_test.reshape(-1,1), X_test)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
mean_squared_error(y_train_actual, train_pred_actual)
# Out:
# 3.0338083164412506

# %%
mean_squared_error(y_val_actual, val_pred_actual)
# Out:
# 7.113129737720069

# %%
mse = mean_squared_error(y_test_actual, test_pred_actual)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_actual, test_pred_actual)
r2 = r2_score(y_test_actual, test_pred_actual)

print("TEST RESULTS:")
print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# TEST RESULTS:
# MSE: 27.79670334045065
# RMSE: 5.272257897756012
# MAE: 4.207041315310407
# R2: 0.9497117779939135

# %% [markdown]
# PLOT PREDICTED VS ACTUAL

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(y_test_actual, label='Actual')
plt.plot(test_pred_actual, label='Predicted')
plt.legend()
plt.title("Test Set Prediction BBCA")
plt.show()
