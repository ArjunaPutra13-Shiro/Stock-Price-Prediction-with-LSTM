# %% [markdown]
# Import libraries

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import math

# %% [markdown]
# Download AMD data

# %%
df = yf.download("AMD", start="2015-01-01", end="2026-01-01")

df = df[['Close']]
df.dropna(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Log return

# %%
df['Return'] = np.log(df['Close'] / df['Close'].shift(1))
df.dropna(inplace=True)

# %% [markdown]
# Feature Engineering Entropy

# %%
def shannon_entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=True)
    hist = hist[hist > 0]  # remove zeros
    return -np.sum(hist * np.log(hist))

window = 30

entropy_values = []
for i in range(len(df)):
    if i < window:
        entropy_values.append(np.nan)
    else:
        ent = shannon_entropy(df['Return'].iloc[i-window:i])
        entropy_values.append(ent)

df['Entropy'] = entropy_values
df.dropna(inplace=True)

# %% [markdown]
# SPLIT AND Normalize

# %%
features = df[['Close', 'Return', 'Entropy']].values

n = len(features)

train_end = int(n * 0.7)
val_end = int(n * 0.80)

train_data = features[:train_end]
val_data = features[train_end:val_end]
test_data = features[val_end:]

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# --- PARAMETERS ---
time_steps = 30

# --- SCALING ---
scaled_all = scaler.transform(features)

# --- SEQUENCE FUNCTION ---
def create_sequences(full_data, start, end, time_steps):
    X, y = [], []
    for i in range(start, end):
        if i < time_steps:
            continue
        X.append(full_data[i-time_steps:i])
        y.append(full_data[i, 0])
    return np.array(X), np.array(y)

# --- DATA SPLIT ---
X_train, y_train = create_sequences(scaled_all, time_steps, train_end, time_steps)
X_val, y_val = create_sequences(scaled_all, train_end, val_end, time_steps)
X_test, y_test = create_sequences(scaled_all, val_end, n, time_steps)

# %% [markdown]
# LSTM MODEL TRAINING

# %%
model = Sequential([
    LSTM(128, return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])

model.compile(optimizer='adamW', loss='mse')

from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(patience=5, restore_best_weights=True)

model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0173 - val_loss: 0.0013
# Epoch 2/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3459e-04 - val_loss: 0.0014
# Epoch 3/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.1038e-04 - val_loss: 0.0013
# Epoch 4/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.7148e-04 - val_loss: 0.0013
# Epoch 5/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.4116e-04 - val_loss: 0.0010
# Epoch 6/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8519e-04 - val_loss: 0.0010
# Epoch 7/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8824e-04 - val_loss: 8.7379e-04
# Epoch 8/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3249e-04 - val_loss: 0.0010
# Epoch 9/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9987e-04 - val_loss: 8.8846e-04
# Epoch 10/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1398e-04 - val_loss: 7.8828e-04
# Epoch 11/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6278e-04 - val_loss: 6.9578e-04
# Epoch 12/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6470e-04 - val_loss: 6.6139e-04
# Epoch 13/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6827e-04 - val_loss: 6.2162e-04
# Epoch 14/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4609e-04 - val_loss: 7.7913e-04
# Epoch 15/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1520e-04 - val_loss: 5.9462e-04
# Epoch 16/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9567e-04 - val_loss: 5.4368e-04
# Epoch 17/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7888e-04 - val_loss: 5.8542e-04
# Epoch 18/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.7876e-04 - val_loss: 5.5543e-04
# Epoch 19/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8316e-04 - val_loss: 4.8535e-04
# Epoch 20/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6689e-04 - val_loss: 4.8534e-04
# Epoch 21/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7191e-04 - val_loss: 5.1579e-04
# Epoch 22/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0374e-04 - val_loss: 6.2081e-04
# Epoch 23/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8220e-04 - val_loss: 4.6122e-04
# Epoch 24/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8209e-04 - val_loss: 4.5915e-04
# Epoch 25/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6541e-04 - val_loss: 5.3842e-04
# Epoch 26/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4418e-04 - val_loss: 7.9909e-04
# Epoch 27/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.3810e-04 - val_loss: 6.6297e-04
# Epoch 28/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4873e-04 - val_loss: 4.2286e-04
# Epoch 29/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0909e-04 - val_loss: 4.1684e-04
# Epoch 30/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4883e-04 - val_loss: 4.5832e-04
# Epoch 31/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1456e-04 - val_loss: 4.1070e-04
# Epoch 32/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1597e-04 - val_loss: 5.0305e-04
# Epoch 33/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5647e-04 - val_loss: 5.0999e-04
# Epoch 34/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1579e-04 - val_loss: 3.8008e-04
# Epoch 35/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9233e-04 - val_loss: 3.7861e-04
# Epoch 36/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1231e-04 - val_loss: 4.2076e-04
# Epoch 37/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4357e-04 - val_loss: 4.1700e-04
# Epoch 38/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1867e-04 - val_loss: 3.6713e-04
# Epoch 39/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1098e-04 - val_loss: 3.6050e-04
# Epoch 40/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0419e-04 - val_loss: 3.9480e-04
# Epoch 41/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9710e-04 - val_loss: 3.6111e-04
# Epoch 42/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8228e-04 - val_loss: 3.5526e-04
# Epoch 43/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1522e-04 - val_loss: 4.2125e-04
# Epoch 44/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9995e-04 - val_loss: 6.4184e-04
# Epoch 45/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8839e-04 - val_loss: 3.7436e-04
# Epoch 46/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7524e-04 - val_loss: 3.6691e-04
# Epoch 47/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7792e-04 - val_loss: 3.3710e-04
# Epoch 48/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2509e-04 - val_loss: 3.5600e-04
# Epoch 49/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8953e-04 - val_loss: 3.9711e-04
# Epoch 50/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7065e-04 - val_loss: 4.0117e-04
# Epoch 51/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7110e-04 - val_loss: 3.4852e-04
# Epoch 52/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7784e-04 - val_loss: 4.2937e-04

# %% [markdown]
# EVALUATION

# %%
train_pred = model.predict(X_train)
val_pred   = model.predict(X_val)
test_pred  = model.predict(X_test)

def inverse_transform(pred, X):
    temp = np.zeros((len(pred), X.shape[2]))
    temp[:, 0] = pred[:, 0]
    return scaler.inverse_transform(temp)[:, 0]

train_pred_actual = inverse_transform(train_pred, X_train)
val_pred_actual   = inverse_transform(val_pred, X_val)
test_pred_actual  = inverse_transform(test_pred, X_test)

y_train_actual = inverse_transform(y_train.reshape(-1,1), X_train)
y_val_actual   = inverse_transform(y_val.reshape(-1,1), X_val)
y_test_actual  = inverse_transform(y_test.reshape(-1,1), X_test)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
mean_squared_error(y_train_actual, train_pred_actual)
# Out:
# 4.625796175593453

# %%
mean_squared_error(y_val_actual, val_pred_actual)
# Out:
# 8.661025796025202

# %%
mse = mean_squared_error(y_test_actual, test_pred_actual)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_actual, test_pred_actual)
r2 = r2_score(y_test_actual, test_pred_actual)

print("TEST RESULTS:")
print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# TEST RESULTS:
# MSE: 43.23987341944626
# RMSE: 6.5757032642483395
# MAE: 4.606381760703559
# R2: 0.9685564517158295

# %% [markdown]
# PLOT PREDICTED VS ACTUAL

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(y_test_actual, label='Actual')
plt.plot(test_pred_actual, label='Predicted')
plt.legend()
plt.title("Test Set Prediction AMD")
plt.show()
